# %% [markdown]
# **Chest X-Ray Pneumonia Classification**
#
# The dataset is organized into 3 folders (train, test, val) and contains subfolders for each image category (Pneumonia/Normal). There are 5,863 X-Ray images (JPEG) and 2 categories (Pneumonia/Normal).
#
# Chest X-ray images (anterior-posterior) were selected from retrospective cohorts of pediatric patients of one to five years old from Guangzhou Women and Children’s Medical Center, Guangzhou. All chest X-ray imaging was performed as part of patients’ routine clinical care.
#
# For the analysis of chest x-ray images, all chest radiographs were initially screened for quality control by removing all low quality or unreadable scans. The diagnoses for the images were then graded by two expert physicians before being cleared for training the AI system. In order to account for any grading errors, the evaluation set was also checked by a third expert.
#
# Dataset Link - https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
#
# Acknowledgements Data: https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# License: CC BY 4.0
#
# Citation: http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5
#
# **Importing the libraries**
#
#
# We will design a Deep Learning Model to classify the images. We will be using Tensorflow 2.0 for the Pneumonia Classification.
#
# Tensorflow Documentation -https://www.tensorflow.org/tutorials
#
# Keras Documentation - https://keras.io/

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

import numpy as np
import SimpleITK as sitk
import cv2 as cv
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# Preprocessing the images

# %%
image_size = 256       #resize all images to 256*256

labels = ['NORMAL', 'PNEUMONIA']          #labels from the folders

# %%
def create_training_data(data_dir):              #creating the training data
    
    images = []
    
    for label in labels:
        dir = os.path.join(data_dir,label)
        class_num = labels.index(label)
        
        for image in os.listdir(dir):    #going through all the images in different folders and resizing them
            
            image_read = cv.imread(os.path.join(dir,image),cv.IMREAD_GRAYSCALE)
            image_resized = cv.resize(image_read,(image_size,image_size))
            images.append([image_resized,class_num])
            
    return np.array(images)

# %%
train = create_training_data('/kaggle/input/chest-xray-pneumonia/chest_xray/train')
test = create_training_data('/kaggle/input/chest-xray-pneumonia/chest_xray/test')
val = create_training_data('/kaggle/input/chest-xray-pneumonia/chest_xray/val')

# %%
train.shape
# Out:
# (5216, 2)

# %%
test.shape
# Out:
# (624, 2)

# %%
val.shape
# Out:
# (16, 2)

# %% [markdown]
# Visualizing some images

# %%
plt.imshow(train[1][0], cmap='gray')
print(labels[train[1][1]])
# Out:
# NORMAL

# %%
plt.imshow(train[5000][0], cmap='gray')
print(labels[train[5000][1]])
# Out:
# PNEUMONIA

# %% [markdown]
# Loading the Images and Labels together

# %%
X = []
y = []

for feature, label in train:
    X.append(feature)          #appending all images
    y.append(label)            #appending all labels

for feature, label in test:
    X.append(feature)
    y.append(label)

# %% [markdown]
# Reshaping dimensions before feeding them to the neural network

# %%
X_new = np.array(X).reshape(-1, image_size, image_size, 1)
y_new = np.array(y)
y_new = np.expand_dims(y_new, axis =1)

# %% [markdown]
# If we go through the dataset, we see that there are a lot more Pneumonia images than Normal images. So we load the images from train and test set together, and split them using the train_test_split (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# We will use 20% of the images for testing and the remaining 80% for training the Neural network.
#
# The Validation images (val) will not be shown to the neural network and will be used later to see on how the neural network performs on predicting images, that it has never seen before.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, random_state = 32)

# %%
X_train.shape
# Out:
# (4672, 256, 256, 1)

# %%
y_train.shape
# Out:
# (4672, 1)

# %%
X_train = X_train / 255            # normalizing
X_test = X_test / 255

# %% [markdown]
# **Creating the CNN Model:**
#
# Convolutional Neural Network (CNN) Detailed description- https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53

# %%
i = Input(X_train.shape[1:])                                        # Input Layer

a = Conv2D(32, (3,3), activation ='relu', padding = 'same')(i)      # Convolution
a = BatchNormalization()(a)                                         # Batch Normalization
a = Conv2D(32, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = MaxPooling2D(2,2)(a)                                            # Max Pooling

a = Conv2D(64, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = Conv2D(64, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = MaxPooling2D(2,2)(a)

a = Conv2D(128, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = Conv2D(128, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = MaxPooling2D(2,2)(a)

a = Conv2D(256, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = Conv2D(256, (3,3), activation ='relu', padding = 'same')(a)
a = BatchNormalization()(a)
a = MaxPooling2D(2,2)(a)

a = Flatten()(a)                                                      # Flatten
a = Dense(512, activation = 'relu')(a)                               # Fully Connected layer
a = Dropout(0.4)(a)
a = Dense(512, activation = 'relu')(a)
a = Dropout(0.3)(a)
a = Dense(512, activation = 'relu')(a)
a = Dropout(0.1)(a)

a = Dense(1, activation = 'sigmoid')(a)                               # Output Layer

model = Model(i,a)

# %% [markdown]
# Compiling and viewing the model summary

# %%
model.compile(optimizer=Adam(lr = 0.0001), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 256, 256, 32)      320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 128, 64)      18496
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               33554944
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 35,256,289
# Trainable params: 35,254,369
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# **Data Augmentation**
#
# Data augmentation - https://www.tensorflow.org/tutorials/images/data_augmentation

# %%
batch_size = 4

train_gen = ImageDataGenerator(rotation_range=10,
                                   horizontal_flip = True,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   rescale=1.,
                                   zoom_range=0.2,
                                   fill_mode='nearest',
                                   cval=0)

train_generator = train_gen.flow(X_train,y_train,batch_size)
steps_per_epoch = X_train.shape[0]//batch_size

# %%
checkpoint = ModelCheckpoint('Pneumonia1.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

#to save the model - epochs with best validation loss

# %% [raw]
# Training the model:

# %%
r = model.fit(train_generator, validation_data=(X_test, y_test), steps_per_epoch = steps_per_epoch, epochs= 15,
                       callbacks = [checkpoint])
# Out:
# Train for 1168 steps, validate on 1168 samples
# Epoch 1/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.9611 - accuracy: 0.8193
# Epoch 00001: val_loss improved from inf to 1.12999, saving model to Pneumonia1.h5
# 1168/1168 [==============================] - 42s 36ms/step - loss: 0.9609 - accuracy: 0.8191 - val_loss: 1.1300 - val_accuracy: 0.7003
# Epoch 2/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.6501 - accuracy: 0.8483
# Epoch 00002: val_loss improved from 1.12999 to 0.20856, saving model to Pneumonia1.h5
# 1168/1168 [==============================] - 40s 34ms/step - loss: 0.6511 - accuracy: 0.8482 - val_loss: 0.2086 - val_accuracy: 0.9281
# Epoch 3/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.4595 - accuracy: 0.8632
# Epoch 00003: val_loss did not improve from 0.20856
# 1168/1168 [==============================] - 40s 34ms/step - loss: 0.4588 - accuracy: 0.8634 - val_loss: 0.2417 - val_accuracy: 0.9195
# Epoch 4/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.8683
# Epoch 00004: val_loss improved from 0.20856 to 0.20610, saving model to Pneumonia1.h5
# 1168/1168 [==============================] - 40s 35ms/step - loss: 0.4221 - accuracy: 0.8684 - val_loss: 0.2061 - val_accuracy: 0.9204
# Epoch 5/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.3462 - accuracy: 0.8856
# Epoch 00005: val_loss improved from 0.20610 to 0.14849, saving model to Pneumonia1.h5
# 1168/1168 [==============================] - 39s 34ms/step - loss: 0.3459 - accuracy: 0.8857 - val_loss: 0.1485 - val_accuracy: 0.9452
# Epoch 6/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.3004 - accuracy: 0.8985
# Epoch 00006: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 39s 33ms/step - loss: 0.3002 - accuracy: 0.8985 - val_loss: 0.1748 - val_accuracy: 0.9469
# Epoch 7/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2934 - accuracy: 0.8997
# Epoch 00007: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 38s 33ms/step - loss: 0.2930 - accuracy: 0.8998 - val_loss: 0.2410 - val_accuracy: 0.9272
# Epoch 8/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2749 - accuracy: 0.9067
# Epoch 00008: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.2761 - accuracy: 0.9062 - val_loss: 0.8050 - val_accuracy: 0.7389
# Epoch 9/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9143
# Epoch 00009: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.2550 - accuracy: 0.9142 - val_loss: 0.2230 - val_accuracy: 0.9110
# Epoch 10/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2358 - accuracy: 0.9134
# Epoch 00010: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.2358 - accuracy: 0.9133 - val_loss: 0.4077 - val_accuracy: 0.8416
# Epoch 11/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2219 - accuracy: 0.9217
# Epoch 00011: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.2218 - accuracy: 0.9217 - val_loss: 0.2137 - val_accuracy: 0.9247
# Epoch 12/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.2145 - accuracy: 0.9246
# Epoch 00012: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.2148 - accuracy: 0.9244 - val_loss: 0.1550 - val_accuracy: 0.9563
# Epoch 13/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2047 - accuracy: 0.9275
# Epoch 00013: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 37s 31ms/step - loss: 0.2050 - accuracy: 0.9274 - val_loss: 0.1964 - val_accuracy: 0.9409
# Epoch 14/15
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2011 - accuracy: 0.9280
# Epoch 00014: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.2009 - accuracy: 0.9281 - val_loss: 0.1503 - val_accuracy: 0.9418
# Epoch 15/15
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.1885 - accuracy: 0.9355
# Epoch 00015: val_loss did not improve from 0.14849
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.1887 - accuracy: 0.9354 - val_loss: 0.1749 - val_accuracy: 0.9426

# %% [markdown]
# Plotting the Losses

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %% [markdown]
# Loading model to try and improve further:

# %%
new_model = tf.keras.models.load_model('Pneumonia1.h5')   #loading model to train further

# %%
new_model.compile(optimizer = Adam(lr = 0.00001), loss = 'binary_crossentropy', metrics = ['accuracy']) 

checkpoint1 = ModelCheckpoint('Pneumonia2.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

batch_size = 4

r1 = new_model.fit(train_generator, validation_data=(X_test, y_test), steps_per_epoch = steps_per_epoch, epochs= 10,
                       callbacks = [checkpoint1])
# Out:
# Train for 1168 steps, validate on 1168 samples
# Epoch 1/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2343 - accuracy: 0.9183
# Epoch 00001: val_loss improved from inf to 0.15168, saving model to Pneumonia2.h5
# 1168/1168 [==============================] - 39s 34ms/step - loss: 0.2353 - accuracy: 0.9180 - val_loss: 0.1517 - val_accuracy: 0.9443
# Epoch 2/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2237 - accuracy: 0.9192
# Epoch 00002: val_loss did not improve from 0.15168
# 1168/1168 [==============================] - 38s 33ms/step - loss: 0.2233 - accuracy: 0.9193 - val_loss: 0.1907 - val_accuracy: 0.9298
# Epoch 3/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.2030 - accuracy: 0.9307
# Epoch 00003: val_loss improved from 0.15168 to 0.14277, saving model to Pneumonia2.h5
# 1168/1168 [==============================] - 39s 33ms/step - loss: 0.2029 - accuracy: 0.9307 - val_loss: 0.1428 - val_accuracy: 0.9503
# Epoch 4/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9290
# Epoch 00004: val_loss did not improve from 0.14277
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.1925 - accuracy: 0.9292 - val_loss: 0.1462 - val_accuracy: 0.9469
# Epoch 5/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9337
# Epoch 00005: val_loss did not improve from 0.14277
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.1810 - accuracy: 0.9334 - val_loss: 0.1608 - val_accuracy: 0.9452
# Epoch 6/10
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.1672 - accuracy: 0.9366
# Epoch 00006: val_loss improved from 0.14277 to 0.12289, saving model to Pneumonia2.h5
# 1168/1168 [==============================] - 39s 33ms/step - loss: 0.1671 - accuracy: 0.9366 - val_loss: 0.1229 - val_accuracy: 0.9580
# Epoch 7/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.1736 - accuracy: 0.9372
# Epoch 00007: val_loss did not improve from 0.12289
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.1737 - accuracy: 0.9371 - val_loss: 0.1453 - val_accuracy: 0.9521
# Epoch 8/10
# 1166/1168 [============================>.] - ETA: 0s - loss: 0.1731 - accuracy: 0.9389
# Epoch 00008: val_loss did not improve from 0.12289
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.1735 - accuracy: 0.9386 - val_loss: 0.1509 - val_accuracy: 0.9426
# Epoch 9/10
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.1582 - accuracy: 0.9415
# Epoch 00009: val_loss did not improve from 0.12289
# 1168/1168 [==============================] - 37s 32ms/step - loss: 0.1581 - accuracy: 0.9416 - val_loss: 0.1832 - val_accuracy: 0.9366
# Epoch 10/10
# 1167/1168 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9441
# Epoch 00010: val_loss did not improve from 0.12289
# 1168/1168 [==============================] - 38s 32ms/step - loss: 0.1579 - accuracy: 0.9441 - val_loss: 0.2290 - val_accuracy: 0.9092

# %% [markdown]
# Loading Final Model for predictions:

# %%
final_model = tf.keras.models.load_model('Pneumonia2.h5')

# %% [markdown]
# Predictions:

# %%
pred = final_model.predict(X_test, batch_size = 8)
pred
# Out:
# array([[0.00545025],
#        [0.01576078],
#        [0.9899922 ],
#        ...,
#        [0.00449841],
#        [0.01703322],
#        [0.8989185 ]], dtype=float32)

# %% [markdown]
# Setting all predictions above 0.5 to 1:

# %%
pred_final = np.where(pred>0.5,1,0)
pred_final
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [1]])

# %% [markdown]
# Confusion Matrix:

# %%
# Get the confusion matrix
CM = confusion_matrix(y_test, pred_final)

fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(8,8))
plt.title('Confusion matrix')
plt.xticks(range(2), ['Normal','Pneumonia'], fontsize=10)
plt.yticks(range(2), ['Normal','Pneumonia'], fontsize=10)
plt.show()

# %%
def perf_measure(y_test, pred_final):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(pred_final)): 
        if y_test[i]==pred_final[i]==1:
           TP += 1
        if y_test[i]==1 and y_test[i]!=pred_final[i]:
           FP += 1
        if y_test[i]==pred_final[i]==0:
           TN += 1
        if y_test[i]==0 and y_test[i]!=pred_final[i]:
           FN += 1

    return(TP, FP, TN, FN)

# %%
tp, fp, tn ,fn = perf_measure(y_test,pred_final)

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f_score = (2*precision*recall)/(precision+recall)

print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))
print("F-Score is {:.2f}".format(f_score))
# Out:
# Recall of the model is 0.98
# Precision of the model is 0.96
# F-Score is 0.97
